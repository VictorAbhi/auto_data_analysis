# %%
import pandas as pd
import numpy as np

# %%
#making dataframe, reading csv file
df = pd.read_csv("auto.csv")

# %%
print("First 5 rows of the dataframe")
df.head()
# Out:
# First 5 rows of the dataframe
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
#  create headers list
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
     "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
     "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
     "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)
# Out:
# headers
#  ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']

# %%
#  adding headers to each column
df.columns = headers
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
# 5          1               158         audi       gas        std         four
# 6          1                 ?         audi       gas        std         four
# 7          1               158         audi       gas      turbo         four
# 8          0                 ?         audi       gas      turbo          two
# 9          2               192          bmw       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# replace "?" symbol with naN values so that dropna() can remove the missing lines
df1 = df.replace("?", np.NaN)
df1
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# drop the missing values along the column "price"
df = df1.dropna(subset=["price"], axis = 0)
df.head(20)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3               NaN  alfa-romero       gas        std
# 1           1               NaN  alfa-romero       gas        std
# 2           2               164         audi       gas        std
# 3           2               164         audi       gas        std
# 4           2               NaN         audi       gas        std
# 5           1               158         audi       gas        std
# 6           1               NaN         audi       gas        std
# 7           1               158         audi       gas      turbo
# 9           2               192          bmw       gas        std
# 10          0               192          bmw       gas        std
# 11          0               188          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          1               NaN          bmw       gas        std
# ...

# %%
# data types
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# summary of data in each columns
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
# describe all the columns in 'df'
df.describe(include="all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   204.000000               204     204       204        204
# unique         NaN                52      22         2          2
# top            NaN                 ?  toyota       gas        std
# freq           NaN                40      32       184        167
# mean      0.823529               NaN     NaN       NaN        NaN
# std       1.239035               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           204        204          204             204  204.000000  ...
# ...

# %%
# describe any of the columns
df[['length','compression-ratio']].describe()
# Out:
#            length  compression-ratio
# count  204.000000         204.000000
# mean   174.075000          10.148137
# std     12.362123           3.981000
# min    141.100000           7.000000
# 25%    166.300000           8.575000
# 50%    173.200000           9.000000
# 75%    183.200000           9.400000
# max    208.100000          23.000000

# %%
# another method to check your database
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          204 non-null    int64
#  1   normalized-losses  204 non-null    object
#  2   make               204 non-null    object
#  3   fuel-type          204 non-null    object
#  4   aspiration         204 non-null    object
#  5   num-of-doors       204 non-null    object
#  6   body-style         204 non-null    object
#  7   drive-wheels       204 non-null    object
#  8   engine-location    204 non-null    object
#  9   wheel-base         204 non-null    float64
#  10  length             204 non-null    float64
#  11  width              204 non-null    float64
#  12  height             204 non-null    float64
#  13  curb-weight        204 non-null    int64
#  14  engine-type        204 non-null    object
#  15  num-of-cylinders   204 non-null    object
# ...

# %%
df.to_csv('lab1-outcome.csv')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
# identify the missing data
missing_data = df.isnull()
missing_data.head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
not_missing_data = df.notnull()
not_missing_data.head()
# Out:
#    symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0       True              False  True       True        True          True
# 1       True              False  True       True        True          True
# 2       True               True  True       True        True          True
# 3       True               True  True       True        True          True
# 4       True              False  True       True        True          True
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0        True          True             True        True  ...         True
# 1        True          True             True        True  ...         True
# 2        True          True             True        True  ...         True
# 3        True          True             True        True  ...         True
# 4        True          True             True        True  ...         True
#
# ...

# %%
# count values in each columns
for column in missing_data.columns.values:
    print(column)
    print(missing_data[column].value_counts())
    print(" ")
# Out:
# symboling
# False    204
# Name: symboling, dtype: int64
#
# normalized-losses
# False    204
# Name: normalized-losses, dtype: int64
#
# make
# False    204
# Name: make, dtype: int64
#
# fuel-type
# False    204
# Name: fuel-type, dtype: int64
#
# aspiration
# False    204
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    204
# Name: num-of-doors, dtype: int64
#
# body-style
# False    204
# Name: body-style, dtype: int64
#
# drive-wheels
# False    204
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    204
# Name: engine-location, dtype: int64
#
# wheel-base
# False    204
# Name: wheel-base, dtype: int64
#
# length
# False    204
# Name: length, dtype: int64
#
# width
# False    204
# Name: width, dtype: int64
#
# height
# False    204
# Name: height, dtype: int64
#
# curb-weight
# False    204
# Name: curb-weight, dtype: int64
#
# engine-type
# False    204
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    204
# ...

# %%
# calculate mean values
avg_norm_loss=df["normalized-losses"].astype("float").mean()
print("Average of normalized losses: ", avg_norm_loss )
# Out:
# Average of normalized losses:  122.0

# %%
# replace nan values with mean
df["normalized-losses"].replace(np.nan,avg_norm_loss,inplace=True)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\3426369765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["normalized-losses"].replace(np.nan,avg_norm_loss,inplace=True)

# %%
df["normalized-losses"]
# Out:
# 0      122.0
# 1      122.0
# 2        164
# 3        164
# 4      122.0
#        ...
# 199       95
# 200       95
# 201       95
# 202       95
# 203       95
# Name: normalized-losses, Length: 200, dtype: object

# %%
df["bore"].dtype
# Out:
# dtype('O')

# %%
avg_bore = df["bore"].astype('float').mean()

# %%
df["bore"].replace(np.nan,avg_bore,inplace=True)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1705617110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bore"].replace(np.nan,avg_bore,inplace=True)

# %%
df["bore"]
# Out:
# 0      3.47
# 1      2.68
# 2      3.19
# 3      3.19
# 4      3.19
#        ...
# 199    3.78
# 200    3.78
# 201    3.58
# 202    3.01
# 203    3.78
# Name: bore, Length: 200, dtype: object

# %%
df['stroke'].dtype
# Out:
# dtype('O')

# %%
avg_stroke = df['stroke'].astype('float').mean(axis=0)
avg_stroke
# Out:
# 3.2598469387755036

# %%
df['stroke'].replace(np.nan,avg_stroke,inplace=True)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\2771997189.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['stroke'].replace(np.nan,avg_stroke,inplace=True)

# %%
df['stroke'].iloc[5:10]
# Out:
# 5     3.40
# 6     3.40
# 7     3.40
# 9     2.80
# 10    2.80
# Name: stroke, dtype: object

# %%
df['horsepower'].dtype
# Out:
# dtype('O')

# %%
avg_horsepower=df['horsepower'].astype('float').mean()
avg_horsepower
# Out:
# 103.35858585858585

# %%
df['horsepower'].replace(np.nan,avg_horsepower,inplace=True)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1960132223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower'].replace(np.nan,avg_horsepower,inplace=True)

# %%
df['horsepower']
# Out:
# 0      111
# 1      154
# 2      102
# 3      115
# 4      110
#       ...
# 199    114
# 200    160
# 201    134
# 202    106
# 203    114
# Name: horsepower, Length: 200, dtype: object

# %%
df['peak-rpm'].dtype
# Out:
# dtype('O')

# %%
avg_peak = df['peak-rpm'].astype('float').mean()
print("Average of peak-rpm: ",avg_peak)
# Out:
# Average of peak-rpm:  5118.181818181818

# %%
df['peak-rpm'].replace(np.nan,avg_peak,inplace=True)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\417154666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['peak-rpm'].replace(np.nan,avg_peak,inplace=True)

# %%
df['peak-rpm'].head()
# Out:
# 0    5000
# 1    5000
# 2    5500
# 3    5500
# 4    5500
# Name: peak-rpm, dtype: object

# %%
df['num-of-doors'].value_counts()
# Out:
# four    113
# two      85
# Name: num-of-doors, dtype: int64

# %%
# calculate most common type
common_door = df['num-of-doors'].value_counts().idxmax()

# %%
# replace with frequency
df['num-of-doors'].replace(np.nan,common_door,inplace=True)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\4223814795.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num-of-doors'].replace(np.nan,common_door,inplace=True)

# %%
df['num-of-doors']
# Out:
# 0       two
# 1       two
# 2      four
# 3      four
# 4       two
#        ...
# 199    four
# 200    four
# 201    four
# 202    four
# 203    four
# Name: num-of-doors, Length: 200, dtype: object

# %%
# drop whole row with NaN in "price" column
df.dropna(subset=["price"], axis=0,inplace=True)
df
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\3898508739.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["price"], axis=0,inplace=True)
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            1             122.0  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2             122.0         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# ...

# %%
# convert data types to proper format
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1378011685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1378011685.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1378011685.py:4: SettingWithCopyWarning:
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# <h1>Data Standardization</h1>
# <p>Data is usually collected from different agencies in different formats. (Data standardization is also a term for a particular type of data normalization where we subtract the mean and divide by the standard deviation.)</p>
#
# <h2>What is standardization?</h2>
# <p>Standardization is the process of transforming data into a common format, allowing the researcher to make the meaningful comparison.</p>

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# convert mpg to L/100km by mathematical operation (235 divide by mpg)
df['city-L/100km'] = 235/df["city-mpg"]
df.head()
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\745289596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city-L/100km'] = 235/df["city-mpg"]
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# ...

# %%
df['highway-L/100km'] = 235/df['highway-mpg']
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          1                122  alfa-romero        std          two
# 2          2                164         audi        std         four
# 3          2                164         audi        std         four
# 4          2                122         audi        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1    hatchback          rwd           front        94.5  0.822681  ...
# 2        sedan          fwd           front        99.8  0.848630  ...
# 3        sedan          4wd           front        99.4  0.848630  ...
# 4        sedan          fwd           front        99.8  0.851994  ...
#
#      price  city-L/100km  highway-L/100km horsepower-binned  fuel-type-diesel  \
# ...

# %%
df[['length','width','height']]
# Out:
#      length  width  height
# 0     168.8   64.1    48.8
# 1     171.2   65.5    52.4
# 2     176.6   66.2    54.3
# 3     176.6   66.4    54.3
# 4     177.3   66.3    53.1
# ..      ...    ...     ...
# 199   188.8   68.9    55.5
# 200   188.8   68.8    55.5
# 201   188.8   68.9    55.5
# 202   188.8   68.9    55.5
# 203   188.8   68.9    55.5
#
# [200 rows x 3 columns]

# %%
# replace original value by original value / maximum value
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1818575775.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['length'] = df['length']/df['length'].max()
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1818575775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['width'] = df['width']/df['width'].max()

# %%
df[['length','width','height']]
# Out:
#        length     width  height
# 0    0.811148  0.890278    48.8
# 1    0.822681  0.909722    52.4
# 2    0.848630  0.919444    54.3
# 3    0.848630  0.922222    54.3
# 4    0.851994  0.920833    53.1
# ..        ...       ...     ...
# 199  0.907256  0.956944    55.5
# 200  0.907256  0.955556    55.5
# 201  0.907256  0.956944    55.5
# 202  0.907256  0.956944    55.5
# 203  0.907256  0.956944    55.5
#
# [200 rows x 3 columns]

# %%
df['height'] = df['height']/df['height'].max()
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1778652782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['height'] = df['height']/df['height'].max()

# %%
df[['length','width','height']]
# Out:
#        length     width    height
# 0    0.811148  0.890278  0.816054
# 1    0.822681  0.909722  0.876254
# 2    0.848630  0.919444  0.908027
# 3    0.848630  0.922222  0.908027
# 4    0.851994  0.920833  0.887960
# ..        ...       ...       ...
# 199  0.907256  0.956944  0.928094
# 200  0.907256  0.955556  0.928094
# 201  0.907256  0.956944  0.928094
# 202  0.907256  0.956944  0.928094
# 203  0.907256  0.956944  0.928094
#
# [200 rows x 3 columns]

# %%
df["horsepower"] = df['horsepower'].astype("int", copy=True)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\1052028465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horsepower"] = df['horsepower'].astype("int", copy=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# creating the bins
bins = np.linspace(min(df['horsepower']),max(df['horsepower']),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low','Medium','High']

# %%
# use cut function to determine in which group the value belongs to
df['horsepower-binned'] = pd.cut(df['horsepower'],bins,labels=group_names,include_lowest=True)
df[['horsepower','horsepower-binned']].head(20)
# Out:
# C:\Users\adabh\AppData\Local\Temp\ipykernel_16336\3561031566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower-binned'] = pd.cut(df['horsepower'],bins,labels=group_names,include_lowest=True)
#     horsepower horsepower-binned
# 0          111               Low
# 1          154            Medium
# 2          102               Low
# 3          115               Low
# 4          110               Low
# 5          110               Low
# 6          110               Low
# 7          140            Medium
# 9          101               Low
# 10         101               Low
# 11         121            Medium
# 12         121            Medium
# 13         121            Medium
# 14         182            Medium
# ...

# %%
df['horsepower-binned'].value_counts()
# Out:
# Low       152
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["horsepower"], bins=3)

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# assigning dummy variable
dummy_variable_1 = pd.get_dummies(df['fuel-type'])
dummy_variable_1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:201, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:209, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:107, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'fuel-type'
#
# ...

# %%
# renaming for clarity
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel': 'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
df = pd.concat([df,dummy_variable_1], axis=1)
df.drop("fuel-type", axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [53], in <cell line: 2>()
#       1 df = pd.concat([df,dummy_variable_1], axis=1)
# ----> 2 df.drop("fuel-type", axis=1,inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            1                122  alfa-romero        std          two
# 2            2                164         audi        std         four
# 3            2                164         audi        std         four
# 4            2                122         audi        std          two
# ..         ...                ...          ...        ...          ...
# 199         -1                 95        volvo        std         four
# 200         -1                 95        volvo      turbo         four
# 201         -1                 95        volvo        std         four
# 202         -1                 95        volvo      turbo         four
# 203         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
dummy_variable_2 = pd.get_dummies(df['aspiration'])
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dummy_variable_2.rename(columns={'std':'asp-type-std','turbo':'asp-type-turbo'},inplace=True)
dummy_variable_2.head()
# Out:
#    asp-type-std  asp-type-turbo
# 0             1               0
# 1             1               0
# 2             1               0
# 3             1               0
# 4             1               0

# %%
df = pd.concat([df,dummy_variable_2], axis=1)
df.drop("aspiration",axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          1                122  alfa-romero        std          two
# 2          2                164         audi        std         four
# 3          2                164         audi        std         four
# 4          2                122         audi        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1    hatchback          rwd           front        94.5  0.822681  ...
# 2        sedan          fwd           front        99.8  0.848630  ...
# 3        sedan          4wd           front        99.4  0.848630  ...
# 4        sedan          fwd           front        99.8  0.851994  ...
#
#      price  city-L/100km  highway-L/100km horsepower-binned  fuel-type-diesel  \
# ...

# %%
df.to_csv('lab2_cleaned_df.csv')

# %%
df['peak-rpm'].dtype
# Out:
# dtype('float64')

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.051087           0.002021    0.566690
# stroke            -0.051087  1.000000           0.186761    0.100351
# compression-ratio  0.002021  0.186761           1.000000   -0.214162
# horsepower         0.566690  0.100351          -0.214162    1.000000

# %%
import seaborn as sns

# %%
sns.regplot(x="engine-size", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
df[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872337
# price           0.872337  1.000000

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.705115
# price          -0.705115  1.000000

# %%
sns.regplot(x='stroke',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %%
df[['stroke','price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.083296
# price   0.083296  1.000000

# %%
sns.boxplot(x='body-style',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>
