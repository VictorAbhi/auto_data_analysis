# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename = "auto.csv"
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
#reading csv and creating dataframe
df = pd.read_csv(filename,header=None)

# %%
df.columns = headers

# %%
# replace "?" to NaN
df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
#evaluating missing data
missing_data = df.isnull()
missing_data.head(10)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
# 5      False               True  False      False       False         False
# 6      False              False  False      False       False         False
# 7      False               True  False      False       False         False
# 8      False              False  False      False       False         False
# 9      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...    engine-size  \
# 0       False         False            False       False  ...          False
# 1       False         False            False       False  ...          False
# 2       False         False            False       False  ...          False
# 3       False         False            False       False  ...          False
# 4       False         False            False       False  ...          False
# 5       False         False            False       False  ...          False
# 6       False         False            False       False  ...          False
# 7       False         False            False       False  ...          False
# 8       False         False            False       False  ...          False
# 9       False         False            False       False  ...          False
#
#    fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0        False  False   False              False       False     False
# 1        False  False   False              False       False     False
# 2        False  False   False              False       False     False
# 3        False  False   False              False       False     False
# 4        False  False   False              False       False     False
# 5        False  False   False              False       False     False
# 6        False  False   False              False       False     False
# 7        False  False   False              False       False     False
# 8        False  False   False              False       False     False
# 9        False  False   False              False       False     False
#
#    city-mpg  highway-mpg  price
# 0     False        False  False
# 1     False        False  False
# 2     False        False  False
# 3     False        False  False
# 4     False        False  False
# 5     False        False  False
# 6     False        False  False
# 7     False        False  False
# 8     False        False  False
# 9     False        False   True
#
# [10 rows x 26 columns]

# %%
missing_data_list = missing_data.columns.values.tolist()
missing_data_list
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
for column in missing_data_list:
    print(column)
    print(missing_data[column].value_counts())
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
# make
# False    205
# Name: make, dtype: int64
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
# aspiration
# False    205
# Name: aspiration, dtype: int64
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
# body-style
# False    205
# Name: body-style, dtype: int64
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
# engine-location
# False    205
# Name: engine-location, dtype: int64
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
# length
# False    205
# Name: length, dtype: int64
# width
# False    205
# Name: width, dtype: int64
# height
# False    205
# Name: height, dtype: int64
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
# engine-type
# False    205
# Name: engine-type, dtype: int64
# num-of-cylinders
# False    205
# Name: num-of-cylinders, dtype: int64
# engine-size
# False    205
# Name: engine-size, dtype: int64
# fuel-system
# False    205
# Name: fuel-system, dtype: int64
# bore
# False    201
# True       4
# Name: bore, dtype: int64
# stroke
# False    201
# True       4
# Name: stroke, dtype: int64
# compression-ratio
# False    205
# Name: compression-ratio, dtype: int64
# horsepower
# False    203
# True       2
# Name: horsepower, dtype: int64
# peak-rpm
# False    203
# True       2
# Name: peak-rpm, dtype: int64
# city-mpg
# False    205
# Name: city-mpg, dtype: int64
# highway-mpg
# False    205
# Name: highway-mpg, dtype: int64
# price
# False    201
# True       4
# Name: price, dtype: int64

# %%
#average of 'normalized-losses' column
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)
print("Average of normalized-losses:", avg_norm_loss)
# Out:
# Average of normalized-losses: 122.0

# %%
# average of 'bore' column
avg_bore=df['bore'].astype('float').mean(axis=0)
print("Average of bore:", avg_bore)
# Out:
# Average of bore: 3.3297512437810957

# %%
#replace nan with mean value in 'bore' column
df.replace(np.nan,avg_bore,inplace=True)

# %%
df['bore']
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
# 5      3.19
# 6      3.19
# 7      3.19
# 8      3.13
# 9      3.13
# 10     3.50
# 11     3.50
# 12     3.31
# 13     3.31
# 14     3.31
# 15     3.62
# 16     3.62
# 17     3.62
# 18     2.91
# 19     3.03
# 20     3.03
# 21     2.97
# 22     2.97
# 23     3.03
# 24     2.97
# 25     2.97
# 26     2.97
# 27     3.03
# 28     3.34
# 29     3.60
#        ...
# 175    3.31
# 176    3.31
# 177    3.31
# 178    3.27
# 179    3.27
# 180    3.27
# 181    3.27
# 182    3.01
# 183    3.19
# 184    3.01
# 185    3.19
# 186    3.19
# 187    3.01
# 188    3.19
# 189    3.19
# 190    3.19
# 191    3.19
# 192    3.01
# 193    3.19
# 194    3.78
# 195    3.78
# 196    3.78
# 197    3.78
# 198    3.62
# 199    3.62
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: object

# %%
df['stroke']
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
# 5      3.40
# 6      3.40
# 7      3.40
# 8      3.40
# 9      3.40
# 10     2.80
# 11     2.80
# 12     3.19
# 13     3.19
# 14     3.19
# 15     3.39
# 16     3.39
# 17     3.39
# 18     3.03
# 19     3.11
# 20     3.11
# 21     3.23
# 22     3.23
# 23     3.39
# 24     3.23
# 25     3.23
# 26     3.23
# 27     3.39
# 28     3.46
# 29     3.90
#        ...
# 175    3.54
# 176    3.54
# 177    3.54
# 178    3.35
# 179    3.35
# 180    3.35
# 181    3.35
# 182    3.40
# 183    3.40
# 184    3.40
# 185    3.40
# 186    3.40
# 187    3.40
# 188    3.40
# 189    3.40
# 190    3.40
# 191    3.40
# 192    3.40
# 193    3.40
# 194    3.15
# 195    3.15
# 196    3.15
# 197    3.15
# 198    3.15
# 199    3.15
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
#average of stroke column
avg_stroke = df['stroke'].astype(float).mean(axis=0)
avg_stroke
# Out:
# 3.256873195000601

# %%
#replace nan values with mean
df['stroke'].replace(np.nan,avg_stroke)
# Out:
# 0      2.68
# 1      2.68
# 2      3.47
# 3      3.40
# 4      3.40
# 5      3.40
# 6      3.40
# 7      3.40
# 8      3.40
# 9      3.40
# 10     2.80
# 11     2.80
# 12     3.19
# 13     3.19
# 14     3.19
# 15     3.39
# 16     3.39
# 17     3.39
# 18     3.03
# 19     3.11
# 20     3.11
# 21     3.23
# 22     3.23
# 23     3.39
# 24     3.23
# 25     3.23
# 26     3.23
# 27     3.39
# 28     3.46
# 29     3.90
#        ...
# 175    3.54
# 176    3.54
# 177    3.54
# 178    3.35
# 179    3.35
# 180    3.35
# 181    3.35
# 182    3.40
# 183    3.40
# 184    3.40
# 185    3.40
# 186    3.40
# 187    3.40
# 188    3.40
# 189    3.40
# 190    3.40
# 191    3.40
# 192    3.40
# 193    3.40
# 194    3.15
# 195    3.15
# 196    3.15
# 197    3.15
# 198    3.15
# 199    3.15
# 200    3.15
# 201    3.15
# 202    2.87
# 203    3.40
# 204    3.15
# Name: stroke, Length: 205, dtype: object

# %%
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)
# Out:
# Average horsepower: 103.27150976823201

# %%
df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)

# %%
avg_peakrpm=df['peak-rpm'].astype('float').mean(axis=0)
print("Average peak rpm:", avg_peakrpm)
# Out:
# Average peak rpm: 5075.398339036525

# %%
df['peak-rpm'].replace(np.nan, avg_peakrpm, inplace=True)

# %%
#count the values in num-of-doors columns
df['num-of-doors'].value_counts()
# Out:
# four                  114
# two                    89
# 3.3297512437810957      2
# Name: num-of-doors, dtype: int64

# %%
#most common type or object with maximum values
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
df["num-of-doors"].replace(np.nan, "four", inplace=True)

# %%
# simply drop whole row with NaN in "price" column
df.dropna(subset=["price"], axis=0, inplace=True)

# reset index, because we droped two rows
df.reset_index(drop=True, inplace=True)

# %%
#to check the datatypes
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# Convert mpg to L/100km by mathematical operation (235 divided by mpg)
df['city-L/100km'] = 235/df["city-mpg"]

# check your transformed data 
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3           3.32975  alfa-romero       gas        std          two
# 1          3           3.32975  alfa-romero       gas        std          two
# 2          1           3.32975  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base     ...       \
# 0  convertible          rwd           front        88.6     ...
# 1  convertible          rwd           front        88.6     ...
# 2    hatchback          rwd           front        94.5     ...
# 3        sedan          fwd           front        99.8     ...
# 4        sedan          4wd           front        99.4     ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
#
#   highway-L/100km  price city-L/100km
# 0        8.703704  13495    11.190476
# 1        8.703704  16500    11.190476
# 2        9.038462  16500    12.368421
# 3        7.833333  13950     9.791667
# 4       10.681818  17450    13.055556
#
# [5 rows x 27 columns]

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3           3.32975  alfa-romero       gas        std          two
# 1          3           3.32975  alfa-romero       gas        std          two
# 2          1           3.32975  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base     ...       \
# 0  convertible          rwd           front        88.6     ...
# 1  convertible          rwd           front        88.6     ...
# 2    hatchback          rwd           front        94.5     ...
# 3        sedan          fwd           front        99.8     ...
# 4        sedan          4wd           front        99.4     ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
#
#   highway-L/100km  price city-L/100km
# 0        8.703704  13495    11.190476
# 1        8.703704  16500    11.190476
# 2        9.038462  16500    12.368421
# 3        7.833333  13950     9.791667
# 4       10.681818  17450    13.055556
#
# [5 rows x 27 columns]

# %%
#normalizing
# replace (original value) by (original value)/(maximum value)
df['length'] = df['length']/df['length'].max()
df['width'] = df['width']/df['width'].max()

# %%
df['height']
# Out:
# 0      48.8
# 1      48.8
# 2      52.4
# 3      54.3
# 4      54.3
# 5      53.1
# 6      55.7
# 7      55.7
# 8      55.9
# 9      52.0
# 10     54.3
# 11     54.3
# 12     54.3
# 13     54.3
# 14     55.7
# 15     55.7
# 16     53.7
# 17     56.3
# 18     53.2
# 19     52.0
# 20     52.0
# 21     50.8
# 22     50.8
# 23     50.8
# 24     50.6
# 25     50.6
# 26     50.6
# 27     50.6
# 28     59.8
# 29     50.2
#        ...
# 175    53.9
# 176    54.9
# 177    53.9
# 178    52.0
# 179    52.0
# 180    54.1
# 181    54.1
# 182    55.7
# 183    55.7
# 184    55.7
# 185    55.7
# 186    55.7
# 187    55.7
# 188    55.7
# 189    55.6
# 190    51.4
# 191    55.1
# 192    55.1
# 193    55.1
# 194    56.2
# 195    57.5
# 196    56.2
# 197    57.5
# 198    56.2
# 199    57.5
# 200    55.5
# 201    55.5
# 202    55.5
# 203    55.5
# 204    55.5
# Name: height, Length: 205, dtype: float64

# %%
#normalizing height
df['height']=df['height']/df['height'].max()

# %%
df['height']
# Out:
# 0      0.816054
# 1      0.816054
# 2      0.876254
# 3      0.908027
# 4      0.908027
# 5      0.887960
# 6      0.931438
# 7      0.931438
# 8      0.934783
# 9      0.869565
# 10     0.908027
# 11     0.908027
# 12     0.908027
# 13     0.908027
# 14     0.931438
# 15     0.931438
# 16     0.897993
# 17     0.941472
# 18     0.889632
# 19     0.869565
# 20     0.869565
# 21     0.849498
# 22     0.849498
# 23     0.849498
# 24     0.846154
# 25     0.846154
# 26     0.846154
# 27     0.846154
# 28     1.000000
# 29     0.839465
#          ...
# 175    0.901338
# 176    0.918060
# 177    0.901338
# 178    0.869565
# 179    0.869565
# 180    0.904682
# 181    0.904682
# 182    0.931438
# 183    0.931438
# 184    0.931438
# 185    0.931438
# 186    0.931438
# 187    0.931438
# 188    0.931438
# 189    0.929766
# 190    0.859532
# 191    0.921405
# 192    0.921405
# 193    0.921405
# 194    0.939799
# 195    0.961538
# 196    0.939799
# 197    0.961538
# 198    0.939799
# 199    0.961538
# 200    0.928094
# 201    0.928094
# 202    0.928094
# 203    0.928094
# 204    0.928094
# Name: height, Length: 205, dtype: float64

# %%
plt.hist(df["horsepower"].head(10))
# set x/y labels and plot title
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5,1,'horsepower bins')

# %%
headers
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
#create bin array
df['horsepower'] = df['horsepower'].astype(float)
bins = np.linspace(min(df["horsepower"]), max(df["horsepower"]), 4)
bins
# Out:
# array([  3.32975124,  98.21983416, 193.10991708, 288.        ])

# %%
#apply the function "cut" to determine what each value of df['horsepower'] belongs to
group_names = ['Low', 'Medium', 'High']
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0        111.0            Medium
# 1        111.0            Medium
# 2        154.0            Medium
# 3        102.0            Medium
# 4        115.0            Medium
# 5        110.0            Medium
# 6        110.0            Medium
# 7        110.0            Medium
# 8        140.0            Medium
# 9        160.0            Medium
# 10       101.0            Medium
# 11       101.0            Medium
# 12       121.0            Medium
# 13       121.0            Medium
# 14       121.0            Medium
# 15       182.0            Medium
# 16       182.0            Medium
# 17       182.0            Medium
# 18        48.0               Low
# 19        70.0               Low

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       111
# Medium     88
# High        6
# Name: horsepower-binned, dtype: int64

# %%
plt.bar(group_names, df["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5,1,'horsepower bins')

# %%
# draw historgram of attribute "horsepower" with bins = 3
plt.hist(df["horsepower"], bins = 5)

# set x/y labels and plot title
plt.xlabel("horsepower")
plt.ylabel("count")
plt.title("horsepower bins")
# Out:
# Text(0.5,1,'horsepower bins')

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-L/100km', 'price', 'city-L/100km', 'horsepower-binned'],
#       dtype='object')

# %%
#creating dummy variables
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
df.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3           3.32975  alfa-romero        std          two
# 1          3           3.32975  alfa-romero        std          two
# 2          1           3.32975  alfa-romero        std          two
# 3          2               164         audi        std         four
# 4          2               164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  \
# 0  convertible          rwd           front        88.6  0.811148
# 1  convertible          rwd           front        88.6  0.811148
# 2    hatchback          rwd           front        94.5  0.822681
# 3        sedan          fwd           front        99.8  0.848630
# 4        sedan          4wd           front        99.4  0.848630
#
#        ...        compression-ratio  horsepower  peak-rpm city-mpg  \
# 0      ...                      9.0       111.0      5000       21
# 1      ...                      9.0       111.0      5000       21
# 2      ...                      9.0       154.0      5000       19
# 3      ...                     10.0       102.0      5500       24
# 4      ...                      8.0       115.0      5500       18
#
#   highway-L/100km  price city-L/100km horsepower-binned fuel-type-diesel  \
# 0        8.703704  13495    11.190476            Medium                0
# 1        8.703704  16500    11.190476            Medium                0
# 2        9.038462  16500    12.368421            Medium                0
# 3        7.833333  13950     9.791667            Medium                0
# 4       10.681818  17450    13.055556            Medium                0
#
#    fuel-type-gas
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-L/100km', 'price', 'city-L/100km', 'horsepower-binned'],
#       dtype='object')

# %%
# merge data frame "df" and "dummy_variable_1" 
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "df"
df.drop("fuel-type", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3           3.32975  alfa-romero        std          two
# 1          3           3.32975  alfa-romero        std          two
# 2          1           3.32975  alfa-romero        std          two
# 3          2               164         audi        std         four
# 4          2               164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  \
# 0  convertible          rwd           front        88.6  0.811148
# 1  convertible          rwd           front        88.6  0.811148
# 2    hatchback          rwd           front        94.5  0.822681
# 3        sedan          fwd           front        99.8  0.848630
# 4        sedan          4wd           front        99.4  0.848630
#
#        ...        compression-ratio  horsepower  peak-rpm city-mpg  \
# 0      ...                      9.0       111.0      5000       21
# 1      ...                      9.0       111.0      5000       21
# 2      ...                      9.0       154.0      5000       19
# 3      ...                     10.0       102.0      5500       24
# 4      ...                      8.0       115.0      5500       18
#
#   highway-L/100km  price city-L/100km horsepower-binned fuel-type-diesel  \
# 0        8.703704  13495    11.190476            Medium                0
# 1        8.703704  16500    11.190476            Medium                0
# 2        9.038462  16500    12.368421            Medium                0
# 3        7.833333  13950     9.791667            Medium                0
# 4       10.681818  17450    13.055556            Medium                0
#
#    fuel-type-gas
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 29 columns]

# %%
dummy_variable_2=pd.get_dummies(df['aspiration'])

# %%
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dummy_variable_2.rename(columns={'std':'asp-type-std', 'diesel':'asp-type-turbo'}, inplace=True)

# %%
dummy_variable_2.head()
# Out:
#    aspiration-type-std  turbo
# 0                    1      0
# 1                    1      0
# 2                    1      0
# 3                    1      0
# 4                    1      0

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-L/100km', 'price',
#        'city-L/100km', 'horsepower-binned', 'fuel-type-diesel',
#        'fuel-type-gas'],
#       dtype='object')

# %%
df = pd.concat([df,dummy_variable_2],axis=1)

# %%
df.drop("aspiration",axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make num-of-doors   body-style  \
# 0          3           3.32975  alfa-romero          two  convertible
# 1          3           3.32975  alfa-romero          two  convertible
# 2          1           3.32975  alfa-romero          two    hatchback
# 3          2               164         audi         four        sedan
# 4          2               164         audi         four        sedan
#
#   drive-wheels engine-location  wheel-base    length     width  ...    \
# 0          rwd           front        88.6  0.811148  0.886584  ...
# 1          rwd           front        88.6  0.811148  0.886584  ...
# 2          rwd           front        94.5  0.822681  0.905947  ...
# 3          fwd           front        99.8  0.848630  0.915629  ...
# 4          4wd           front        99.4  0.848630  0.918396  ...
#
#    peak-rpm  city-mpg highway-L/100km  price  city-L/100km horsepower-binned  \
# 0      5000        21        8.703704  13495     11.190476            Medium
# 1      5000        21        8.703704  16500     11.190476            Medium
# 2      5000        19        9.038462  16500     12.368421            Medium
# 3      5500        24        7.833333  13950      9.791667            Medium
# 4      5500        18       10.681818  17450     13.055556            Medium
#
#   fuel-type-diesel fuel-type-gas  aspiration-type-std  turbo
# 0                0             1                    1      0
# 1                0             1                    1      0
# 2                0             1                    1      0
# 3                0             1                    1      0
# 4                0             1                    1      0
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'num-of-doors', 'body-style',
#        'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-L/100km', 'price',
#        'city-L/100km', 'horsepower-binned', 'fuel-type-diesel',
#        'fuel-type-gas', 'aspiration-type-std', 'turbo'],
#       dtype='object')

# %%
df['aspiration-type-std'].value_counts()
# Out:
# 1    168
# 0     37
# Name: aspiration-type-std, dtype: int64

# %%
df.to_csv('auto_cleaned.csv')
